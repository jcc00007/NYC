# %% [markdown]
# # Preprocessing the current listing property from the domain website
# This notebook is to preprocess the listing property data that were scraped from the script.py.

# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import re
import numpy as np

# %% [markdown]
# # Read the Listing Data

# %%
listings_df = pd.read_parquet('../data/landing/listings.parquet')

# %%
listings_df.head()
# Out:
#                                                                                       Location  \
# https://www.domain.com.au/1507-220-spencer-stre...  1507/220 Spencer Street Melbourne VIC 3000
# https://www.domain.com.au/4506-33-rose-lane-mel...        4506/33 Rose Lane Melbourne VIC 3000
# https://www.domain.com.au/1715-220-spencer-stre...  1715/220 Spencer Street Melbourne VIC 3000
# https://www.domain.com.au/3504-220-spencer-stre...  3504/220 Spencer Street Melbourne VIC 3000
# https://www.domain.com.au/512-118-franklin-stre...  512/118 Franklin Street Melbourne VIC 3000
#
#                                                               type_property  \
# https://www.domain.com.au/1507-220-spencer-stre...  Apartment / Unit / Flat
# https://www.domain.com.au/4506-33-rose-lane-mel...  Apartment / Unit / Flat
# https://www.domain.com.au/1715-220-spencer-stre...  Apartment / Unit / Flat
# https://www.domain.com.au/3504-220-spencer-stre...  Apartment / Unit / Flat
# https://www.domain.com.au/512-118-franklin-stre...  Apartment / Unit / Flat
#
#                                                             price  \
# https://www.domain.com.au/1507-220-spencer-stre...         $430pw
# https://www.domain.com.au/4506-33-rose-lane-mel...  $520 Per Week
# https://www.domain.com.au/1715-220-spencer-stre...           $750
# https://www.domain.com.au/3504-220-spencer-stre...  $400 per week
# https://www.domain.com.au/512-118-franklin-stre...           $430
#
#                                                                                          school_names  \
# https://www.domain.com.au/1507-220-spencer-stre...  [Docklands Primary School, University High Sch...
# https://www.domain.com.au/4506-33-rose-lane-mel...  [Docklands Primary School, University High Sch...
# https://www.domain.com.au/1715-220-spencer-stre...  [Docklands Primary School, University High Sch...
# https://www.domain.com.au/3504-220-spencer-stre...  [Docklands Primary School, University High Sch...
# https://www.domain.com.au/512-118-franklin-stre...  [Carlton Gardens Primary School, University Hi...
#
#                                                                             school_distance  \
# https://www.domain.com.au/1507-220-spencer-stre...    [1 km away, 2.1 km away, 0.3 km away]
# https://www.domain.com.au/4506-33-rose-lane-mel...    [1.1 km away, 2 km away, 0.3 km away]
# https://www.domain.com.au/1715-220-spencer-stre...    [1 km away, 2.1 km away, 0.3 km away]
# https://www.domain.com.au/3504-220-spencer-stre...    [1 km away, 2.1 km away, 0.3 km away]
# https://www.domain.com.au/512-118-franklin-stre...  [1.2 km away, 1.3 km away, 0.5 km away]
#
#                                                    LT_resident_pcg owner_pcg  \
# https://www.domain.com.au/1507-220-spencer-stre...             12%       28%
# https://www.domain.com.au/4506-33-rose-lane-mel...             12%       28%
# https://www.domain.com.au/1715-220-spencer-stre...             12%       28%
# https://www.domain.com.au/3504-220-spencer-stre...             12%       28%
# https://www.domain.com.au/512-118-franklin-stre...            None       29%
#
#                                                    family_pcg state     rooms  \
# https://www.domain.com.au/1507-220-spencer-stre...        27%   VIC  [0 Beds]
# https://www.domain.com.au/4506-33-rose-lane-mel...        27%   VIC   [1 Bed]
# https://www.domain.com.au/1715-220-spencer-stre...        27%   VIC  [2 Beds]
# https://www.domain.com.au/3504-220-spencer-stre...        27%   VIC  [0 Beds]
# https://www.domain.com.au/512-118-franklin-stre...        16%   VIC   [1 Bed]
#
#                                                          bath      parking
# https://www.domain.com.au/1507-220-spencer-stre...   [1 Bath]  [− Parking]
# https://www.domain.com.au/4506-33-rose-lane-mel...   [1 Bath]  [− Parking]
# https://www.domain.com.au/1715-220-spencer-stre...  [2 Baths]  [1 Parking]
# https://www.domain.com.au/3504-220-spencer-stre...   [1 Bath]  [− Parking]
# https://www.domain.com.au/512-118-franklin-stre...   [1 Bath]  [− Parking]

# %%
# Set a index for each row
listings_df['link'] = listings_df.index
listings_df.index = range(listings_df.shape[0])

# %%
# check the size of the data
listings_df.shape
# Out:
# (12297, 13)

# %% [markdown]
# # For coulmns as lists, retrieve the actual values

# %%
for i in range(listings_df.shape[0]):
    
    # number of beds
    num_beds_str = listings_df.loc[i, 'rooms']
    if num_beds_str:
        num_beds = re.findall('\d+', num_beds_str[0])
        if num_beds:
            listings_df.loc[i, 'rooms'] = num_beds[0]
        else:
            listings_df.loc[i, 'rooms'] = np.nan
    else:
        listings_df.loc[i, 'rooms'] = np.nan

    
    # number of baths
    num_bath_str = listings_df.loc[i, 'bath']
    if num_bath_str:
        num_bath = re.findall('\d+', num_bath_str[0])
        if num_bath:
            listings_df.loc[i, 'bath'] = num_bath[0]
        else:
            listings_df.loc[i, 'bath'] = np.nan
    else:
        listings_df.loc[i, 'bath'] = np.nan


    # number of parking
    num_parking_str = listings_df.loc[i, 'parking']
    if num_parking_str: 
        num_parking = re.findall('\d+', num_parking_str[0])
        if num_parking:
            listings_df.loc[i, 'parking'] = num_parking[0]
        else:
            listings_df.loc[i, 'parking'] = np.nan        
    else:
        listings_df.loc[i, 'parking'] = np.nan
# Out:
# /var/folders/_9/rb9s3yd952d26d6ytbnwjc3h0000gn/T/ipykernel_10796/3066084528.py:5: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if num_beds_str:
# /var/folders/_9/rb9s3yd952d26d6ytbnwjc3h0000gn/T/ipykernel_10796/3066084528.py:17: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if num_bath_str:
# /var/folders/_9/rb9s3yd952d26d6ytbnwjc3h0000gn/T/ipykernel_10796/3066084528.py:29: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if num_parking_str:

# %%
# Column type changing
# Since int type is not supported for columns with nan, changed to float instead
listings_df['rooms'] = listings_df['rooms'].astype(float)
listings_df['bath'] = listings_df['bath'].astype(float)
listings_df['parking'] = listings_df['parking'].astype(float)

# %% [markdown]
# ## Explode the school columns

# %% [markdown]
# The school column contain three schools in order, the first one being the closest public school, the second one being the second closest public school, the third one being the closest private school, the school distance contain the distance of the three schools in order

# %%
def school_filler(df, i, col, name, dis):
    ''' fill the the distance and name of the ith listing's related school'''
    df.loc[i, col] = name
    df.loc[i, f'{col}_dis'] = dis

# %%
for i in range(listings_df.shape[0]):
    schools = listings_df.loc[i, 'school_names']
    distance = listings_df.loc[i, 'school_distance']
    if type(schools)!=type(None):
        try:
            school_filler(listings_df, i, 'public_1', schools[0], re.findall('(.+)\skm\saway', distance[0])[0])
            school_filler(listings_df, i, 'public_2', schools[1], re.findall('(.+)\skm\saway', distance[1])[0])
            school_filler(listings_df, i, 'private_1', schools[2], re.findall('(.+)\skm\saway', distance[2])[0])
        except IndexError:
            '''when an index error happens, the there's no information about the closest 1st/2nd 
            public and 1st private school and we just leave the cell being nan'''
            pass

# %%
listings_df.head()
# Out:
#                                      Location            type_property  \
# 0  1507/220 Spencer Street Melbourne VIC 3000  Apartment / Unit / Flat
# 1        4506/33 Rose Lane Melbourne VIC 3000  Apartment / Unit / Flat
# 2  1715/220 Spencer Street Melbourne VIC 3000  Apartment / Unit / Flat
# 3  3504/220 Spencer Street Melbourne VIC 3000  Apartment / Unit / Flat
# 4  512/118 Franklin Street Melbourne VIC 3000  Apartment / Unit / Flat
#
#            price                                       school_names  \
# 0         $430pw  [Docklands Primary School, University High Sch...
# 1  $520 Per Week  [Docklands Primary School, University High Sch...
# 2           $750  [Docklands Primary School, University High Sch...
# 3  $400 per week  [Docklands Primary School, University High Sch...
# 4           $430  [Carlton Gardens Primary School, University Hi...
#
#                            school_distance LT_resident_pcg owner_pcg  \
# 0    [1 km away, 2.1 km away, 0.3 km away]             12%       28%
# 1    [1.1 km away, 2 km away, 0.3 km away]             12%       28%
# 2    [1 km away, 2.1 km away, 0.3 km away]             12%       28%
# 3    [1 km away, 2.1 km away, 0.3 km away]             12%       28%
# 4  [1.2 km away, 1.3 km away, 0.5 km away]            None       29%
#
#   family_pcg state  rooms  bath  parking  \
# 0        27%   VIC    0.0   1.0      NaN
# 1        27%   VIC    1.0   1.0      NaN
# 2        27%   VIC    2.0   2.0      1.0
# 3        27%   VIC    0.0   1.0      NaN
# 4        16%   VIC    1.0   1.0      NaN
#
#                                                 link  \
# 0  https://www.domain.com.au/1507-220-spencer-str...
# 1  https://www.domain.com.au/4506-33-rose-lane-me...
# 2  https://www.domain.com.au/1715-220-spencer-str...
# 3  https://www.domain.com.au/3504-220-spencer-str...
# 4  https://www.domain.com.au/512-118-franklin-str...
#
#                          public_1 public_1_dis                public_2  \
# 0        Docklands Primary School            1  University High School
# 1        Docklands Primary School          1.1  University High School
# 2        Docklands Primary School            1  University High School
# 3        Docklands Primary School            1  University High School
# 4  Carlton Gardens Primary School          1.2  University High School
#
#   public_2_dis                               private_1 private_1_dis
# 0          2.1     Eltham College - King Street Campus           0.3
# 1            2  Ozford College - Ozford College Campus           0.3
# 2          2.1     Eltham College - King Street Campus           0.3
# 3          2.1     Eltham College - King Street Campus           0.3
# 4          1.3                       River Nile School           0.5

# %%
# change the type of distance columns to float
listings_df['public_1_dis'] = listings_df['public_1_dis'].astype(float)
listings_df['public_2_dis'] = listings_df['public_2_dis'].astype(float)
listings_df['private_1_dis'] = listings_df['private_1_dis'].astype(float)

# %%
# drop the original column
listings_df.drop(columns = ['school_names', 'school_distance'], inplace = True)

# %% [markdown]
# # Percentage Features value extracting

# %%
for i in range(listings_df.shape[0]):
    # extract the numbers in the percentages
    
    try:
        listings_df.loc[i, 'LT_resident_pcg'] = re.findall('(.+)\%', listings_df.loc[i, 'LT_resident_pcg'])[0]
    except IndexError:
        listings_df.loc[i, 'LT_resident_pcg'] = np.nan
    except TypeError:
        listings_df.loc[i, 'LT_resident_pcg'] = np.nan

    
    try:
        listings_df.loc[i, 'owner_pcg'] = re.findall('(.+)\%', listings_df.loc[i, 'owner_pcg'])[0]
    except IndexError:
        listings_df.loc[i, 'owner_pcg'] = np.nan
    except TypeError:
        listings_df.loc[i, 'owner_pcg'] = np.nan


    try:
        listings_df.loc[i, 'family_pcg'] = re.findall('(.+)\%', listings_df.loc[i, 'family_pcg'])[0]
    except IndexError:
        listings_df.loc[i, 'family_pcg'] = np.nan   
    except TypeError:
        listings_df.loc[i, 'family_pcg'] = np.nan

# %%
# change the type of the percentage columns to float
listings_df['LT_resident_pcg'] = listings_df['LT_resident_pcg'].astype(float)
listings_df['owner_pcg'] = listings_df['owner_pcg'].astype(float)
listings_df['family_pcg'] = listings_df['family_pcg'].astype(float)

# %%
listings_df.head(10)
# Out:
#                                       Location            type_property  \
# 0   1507/220 Spencer Street Melbourne VIC 3000  Apartment / Unit / Flat
# 1         4506/33 Rose Lane Melbourne VIC 3000  Apartment / Unit / Flat
# 2   1715/220 Spencer Street Melbourne VIC 3000  Apartment / Unit / Flat
# 3   3504/220 Spencer Street Melbourne VIC 3000  Apartment / Unit / Flat
# 4   512/118 Franklin Street Melbourne VIC 3000  Apartment / Unit / Flat
# 5  5801/648 Lonsdale Street Melbourne VIC 3000  Apartment / Unit / Flat
# 6    1.2/187 Collins Street Melbourne VIC 3000  Apartment / Unit / Flat
# 7        521/422 Collins St Melbourne VIC 3000  Apartment / Unit / Flat
# 8    603/199 William Street Melbourne VIC 3000  Apartment / Unit / Flat
# 9    1111/568 St Kilda Road Melbourne VIC 3000  Apartment / Unit / Flat
#
#            price  LT_resident_pcg  owner_pcg  family_pcg state  rooms  bath  \
# 0         $430pw             12.0       28.0        27.0   VIC    0.0   1.0
# 1  $520 Per Week             12.0       28.0        27.0   VIC    1.0   1.0
# 2           $750             12.0       28.0        27.0   VIC    2.0   2.0
# 3  $400 per week             12.0       28.0        27.0   VIC    0.0   1.0
# 4           $430              NaN       29.0        16.0   VIC    1.0   1.0
# 5           $800             12.0       20.0        34.0   VIC    2.0   2.0
# 6        $475 pw             37.0       49.0        51.0   VIC    1.0   1.0
# 7    $500 weekly             18.0       28.0        39.0   VIC    1.0   1.0
# 8           $700             22.0       29.0        24.0   VIC    2.0   2.0
# 9           $450              NaN       47.0        56.0   VIC    1.0   1.0
#
#    parking                                               link  \
# 0      NaN  https://www.domain.com.au/1507-220-spencer-str...
# 1      NaN  https://www.domain.com.au/4506-33-rose-lane-me...
# 2      1.0  https://www.domain.com.au/1715-220-spencer-str...
# 3      NaN  https://www.domain.com.au/3504-220-spencer-str...
# 4      NaN  https://www.domain.com.au/512-118-franklin-str...
# 5      NaN  https://www.domain.com.au/5801-648-lonsdale-st...
# 6      NaN  https://www.domain.com.au/1-2-187-collins-stre...
# 7      NaN  https://www.domain.com.au/521-422-collins-st-m...
# 8      NaN  https://www.domain.com.au/603-199-william-stre...
# 9      NaN  https://www.domain.com.au/1111-568-st-kilda-ro...
#
#                          public_1  public_1_dis                public_2  \
# 0        Docklands Primary School           1.0  University High School
# 1        Docklands Primary School           1.1  University High School
# 2        Docklands Primary School           1.0  University High School
# 3        Docklands Primary School           1.0  University High School
# 4  Carlton Gardens Primary School           1.2  University High School
# 5        Docklands Primary School           1.0  University High School
# 6  Carlton Gardens Primary School           1.5  University High School
# 7        Docklands Primary School           1.7  University High School
# 8        Docklands Primary School           1.4  University High School
# 9      South Yarra Primary School           0.9     Prahran High School
#
#    public_2_dis                               private_1  private_1_dis
# 0           2.1     Eltham College - King Street Campus            0.3
# 1           2.0  Ozford College - Ozford College Campus            0.3
# 2           2.1     Eltham College - King Street Campus            0.3
# 3           2.1     Eltham College - King Street Campus            0.3
# 4           1.3                       River Nile School            0.5
# 5           1.9  Ozford College - Ozford College Campus            0.2
# 6           2.3                        Stott's Colleges            0.5
# 7           2.3     Eltham College - King Street Campus            0.4
# 8           2.0  Ozford College - Ozford College Campus            0.3
# 9           1.2          Port Phillip Specialist School            3.4

# %% [markdown]
# # Extract the weekly price

# %%
lease_type = []
for i in range(listings_df.shape[0]):
    # extract the weekly price and lower all the other letters in the price column
    try:
        listings_df.loc[i, 'rent'] = re.findall('\$([\d\,]+)', listings_df.loc[i, 'price'])[0]
        listings_df.loc[i, 'rent'] = listings_df.loc[i, 'rent'].replace(',','')
        listings_df.loc[i, 'price'] = listings_df.loc[i, 'price'].lower()
        if re.findall('[A-z]+',listings_df.loc[i, 'price']) not in lease_type:
            lease_type.append(re.findall('[a-z]+',listings_df.loc[i, 'price']))
    except TypeError:
        pass
    except IndexError:
        pass

# %%
# change the type of the column to float
listings_df['rent'] = listings_df['rent'].astype(float)

# %%
# number of weeks per month constant 
wpm = 4.35
# number of week per year
wpy = wpm * 12
# number of week per season
wps = wpm * 3
for i in range(listings_df.shape[0]):
    # check if the price is weekly or monthly, weekly is assumed if unspecified
    # It has been checked there is no annualy contracts available
    try:
        text = listings_df.loc[i, 'price']
        if 'month' in text or 'mth' in text or 'pm' in text and 'pw' not in text and 'week' not in text:
            listings_df.loc[i, 'rent'] = listings_df.loc[i, 'rent'] / wpm

        elif 'season' in text:
            listings_df.loc[i, 'rent'] = listings_df.loc[i, 'rent'] / wps

        elif 'p.a' in text:
            listings_df.loc[i, 'rent'] = listings_df.loc[i, 'rent'] / wpy
            
        if ('furnished' in text or 'furniture' in text or 'furn' in text) and 'not' not in text:
            listings_df.loc[i, 'is_furnished'] = True
        else:
            listings_df.loc[i, 'is_furnished'] = False 
    except TypeError:
        pass

# %%
listings_df.head()
# Out:
#                                      Location            type_property  \
# 0  1507/220 Spencer Street Melbourne VIC 3000  Apartment / Unit / Flat
# 1        4506/33 Rose Lane Melbourne VIC 3000  Apartment / Unit / Flat
# 2  1715/220 Spencer Street Melbourne VIC 3000  Apartment / Unit / Flat
# 3  3504/220 Spencer Street Melbourne VIC 3000  Apartment / Unit / Flat
# 4  512/118 Franklin Street Melbourne VIC 3000  Apartment / Unit / Flat
#
#            price  LT_resident_pcg  owner_pcg  family_pcg state  rooms  bath  \
# 0         $430pw             12.0       28.0        27.0   VIC    0.0   1.0
# 1  $520 per week             12.0       28.0        27.0   VIC    1.0   1.0
# 2           $750             12.0       28.0        27.0   VIC    2.0   2.0
# 3  $400 per week             12.0       28.0        27.0   VIC    0.0   1.0
# 4           $430              NaN       29.0        16.0   VIC    1.0   1.0
#
#    parking                                               link  \
# 0      NaN  https://www.domain.com.au/1507-220-spencer-str...
# 1      NaN  https://www.domain.com.au/4506-33-rose-lane-me...
# 2      1.0  https://www.domain.com.au/1715-220-spencer-str...
# 3      NaN  https://www.domain.com.au/3504-220-spencer-str...
# 4      NaN  https://www.domain.com.au/512-118-franklin-str...
#
#                          public_1  public_1_dis                public_2  \
# 0        Docklands Primary School           1.0  University High School
# 1        Docklands Primary School           1.1  University High School
# 2        Docklands Primary School           1.0  University High School
# 3        Docklands Primary School           1.0  University High School
# 4  Carlton Gardens Primary School           1.2  University High School
#
#    public_2_dis                               private_1  private_1_dis   rent  \
# 0           2.1     Eltham College - King Street Campus            0.3  430.0
# 1           2.0  Ozford College - Ozford College Campus            0.3  520.0
# 2           2.1     Eltham College - King Street Campus            0.3  750.0
# 3           2.1     Eltham College - King Street Campus            0.3  400.0
# 4           1.3                       River Nile School            0.5  430.0
#
#   is_furnished
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
# save the file to raw
listings_df.to_csv('../data/raw/listings.csv', index = False)
