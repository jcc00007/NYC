# %% [markdown]
# # Preprocessing Postcode data
#
# This notebook we will download and preprocess the postcode data

# %%
import pandas as pd

# %% [markdown]
# ## Download the postcode data to local landing folder

# %%
# %run ../scripts/Postcode_Download.py
# Out:
# File downloaded and saved as: ../data/landing/postcode/australian_postcodes.csv

# %%
postcode_df = pd.read_csv('../data/landing/postcode/australian_postcodes.csv')
print(postcode_df.columns)
# Out:
# Index(['id', 'postcode', 'locality', 'state', 'long', 'lat', 'dc', 'type',
#        'status', 'sa3', 'sa3name', 'sa4', 'sa4name', 'region', 'Lat_precise',
#        'Long_precise', 'SA1_MAINCODE_2011', 'SA1_MAINCODE_2016',
#        'SA2_MAINCODE_2016', 'SA2_NAME_2016', 'SA3_CODE_2016', 'SA3_NAME_2016',
#        'SA4_CODE_2016', 'SA4_NAME_2016', 'RA_2011', 'RA_2016', 'MMM_2015',
#        'MMM_2019', 'ced', 'altitude', 'chargezone', 'phn_code', 'phn_name',
#        'lgaregion', 'lgacode', 'electorate', 'electoraterating'],
#       dtype='object')

# %% [markdown]
# ### Feature selection

# %%
# Define a list of column names to retain
columns_to_retain = ['postcode', 'locality', 'state', 'SA2_MAINCODE_2016', 'SA2_NAME_2016', 'Lat_precise', 'Long_precise']  # Replace with your desired column names

# Filter the DataFrame to retain only the specified columns
postcode_df = postcode_df[columns_to_retain]

# %%
postcode_df
# Out:
#        postcode                        locality state  SA2_MAINCODE_2016  \
# 0           200                             ANU   ACT        801051049.0
# 1           200  Australian National University   ACT        801051049.0
# 2           800                          DARWIN    NT        701011002.0
# 3           800                     DARWIN CITY    NT        701011002.0
# 4           801                          DARWIN    NT        701011002.0
# ...         ...                             ...   ...                ...
# 18508      9013                        BRISBANE   QLD        305011105.0
# 18509      9015                        BRISBANE   QLD        305011105.0
# 18510      9464                    NORTHGATE MC   QLD        302031038.0
# 18511      9726                   GOLD COAST MC   QLD        309101268.0
# 18512      9999                      NORTH POLE   VIC        206041122.0
#
#               SA2_NAME_2016  Lat_precise  Long_precise
# 0                     Acton   -35.277700    149.119000
# 1                     Acton   -35.277700    149.118527
# 2               Darwin City   -12.393279    130.776661
# 3               Darwin City   -12.393279    130.776661
# 4               Darwin City   -12.463440    130.845642
# ...                     ...          ...           ...
# 18508         Brisbane City   -27.469771    153.025124
# 18509         Brisbane City   -27.469771    153.025124
# 18510  Northgate - Virginia   -27.390000    153.066000
# 18511               Bundall   -28.016700    153.400000
# 18512             Melbourne   -37.815207    144.963937
#
# [18513 rows x 7 columns]

# %% [markdown]
# ### Select Victoria region

# %%
vic_postcode = postcode_df[postcode_df['state'] == 'VIC']
# now we don't need state columns anymore
vic_postcode = vic_postcode.drop(columns= 'state')

# %%
vic_postcode
# Out:
#        postcode         locality  SA2_MAINCODE_2016   SA2_NAME_2016  \
# 6185       3000        MELBOURNE        206041122.0       Melbourne
# 6186       3001        MELBOURNE        206041122.0       Melbourne
# 6187       3002   EAST MELBOURNE        206041119.0  East Melbourne
# 6188       3003   WEST MELBOURNE        206041127.0  West Melbourne
# 6189       3004        MELBOURNE        206041126.0       Southbank
# ...         ...              ...                ...             ...
# 18497      8438    SUNSHINE WEST                NaN             NaN
# 18498      8511    SUNSHINE WEST                NaN             NaN
# 18499      8785        DANDENONG        212041311.0       Dandenong
# 18500      8785  DANDENONG SOUTH        212041311.0       Dandenong
# 18512      9999       NORTH POLE        206041122.0       Melbourne
#
#        Lat_precise  Long_precise
# 6185    -37.815207    144.963937
# 6186    -37.813628    144.963058
# 6187    -37.816144    144.980459
# 6188    -37.811450    144.925397
# 6189    -37.830158    144.980459
# ...            ...           ...
# 18497     0.000000      0.000000
# 18498     0.000000      0.000000
# 18499   -37.984781    145.213991
# 18500   -37.984781    145.213991
# 18512   -37.815207    144.963937
#
# [3540 rows x 6 columns]

# %% [markdown]
# aware that there is some data containing 0 Lat_precise	and Long_precis.
#
# Here we assume that any row of data contain NaN is invalid and thus need ot be remove

# %%
# remove all row of data that has nan
vic_postcode = vic_postcode.dropna()
vic_postcode
# Out:
#        postcode         locality  SA2_MAINCODE_2016   SA2_NAME_2016  \
# 6185       3000        MELBOURNE        206041122.0       Melbourne
# 6186       3001        MELBOURNE        206041122.0       Melbourne
# 6187       3002   EAST MELBOURNE        206041119.0  East Melbourne
# 6188       3003   WEST MELBOURNE        206041127.0  West Melbourne
# 6189       3004        MELBOURNE        206041126.0       Southbank
# ...         ...              ...                ...             ...
# 18495      8120        MELBOURNE        206041122.0       Melbourne
# 18496      8205        MELBOURNE        206041122.0       Melbourne
# 18499      8785        DANDENONG        212041311.0       Dandenong
# 18500      8785  DANDENONG SOUTH        212041311.0       Dandenong
# 18512      9999       NORTH POLE        206041122.0       Melbourne
#
#        Lat_precise  Long_precise
# 6185    -37.815207    144.963937
# 6186    -37.813628    144.963058
# 6187    -37.816144    144.980459
# 6188    -37.811450    144.925397
# 6189    -37.830158    144.980459
# ...            ...           ...
# 18495   -37.813628    144.963058
# 18496   -37.813628    144.963058
# 18499   -37.984781    145.213991
# 18500   -37.984781    145.213991
# 18512   -37.815207    144.963937
#
# [3537 rows x 6 columns]

# %% [markdown]
# ### Save the files

# %%
# Save to raw data 
vic_postcode.to_csv('../data/raw/location_postcode.csv',index=False)
