# %% [markdown]
# # Preprocess Crime data

# %% [markdown]
# This notebook will run the `Crime_Download.py` script in the scripts folder to download the crime data to local landing folder
#
# This notebook will then continue preprocessing the data, grouping/counting the crime instance record by location/postcode/time(year)

# %% [markdown]
# ### Import packages

# %%
import pandas as pd

# %%
import geopandas as gpd
from fuzzywuzzy import fuzz

import geopandas as gpd
from shapely.geometry import Point
# Out:
# /home/jcc/.local/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# ## Dowload Crime data to landing folder

# %%
# %run ../scripts/Crime_Download.py
# Out:
# File '../data/landing/crime_stat/crime_stat_2023.xlsx' downloaded successfully.

# %% [markdown]
# ## Read in our desire table/sheet of crime data
# as table 3 store content of Criminal incidents by principal offence, local government area and postcode or suburb/town - April 2013 to March 2023

# %%
# Read the "Table 03" sheet into a DataFrame
sheet_name = "Table 03"
crime_df = pd.read_excel("../data/landing/crime_stat/crime_stat_2023.xlsx", sheet_name=sheet_name)

# %%
crime_df
# Out:
#         Year Year ending Local Government Area  Postcode Suburb/Town Name  \
# 0       2023       March                Alpine      3691         Dederang
# 1       2023       March                Alpine      3691         Dederang
# 2       2023       March                Alpine      3691         Dederang
# 3       2023       March                Alpine      3691         Dederang
# 4       2023       March                Alpine      3691         Dederang
# ...      ...         ...                   ...       ...              ...
# 330929  2014       March          Yarriambiack      3489            Tempy
# 330930  2014       March          Yarriambiack      3489            Tempy
# 330931  2014       March          Yarriambiack      3489            Tempy
# 330932  2014       March          Yarriambiack      3491    Patchewollock
# 330933  2014       March          Yarriambiack      3491    Patchewollock
#
#                             Offence Division  \
# 0                A Crimes against the person
# 1                A Crimes against the person
# 2          B Property and deception offences
# 3          B Property and deception offences
# 4       D Public order and security offences
# ...                                      ...
# 330929     B Property and deception offences
# 330930     B Property and deception offences
# 330931         E Justice procedures offences
# 330932           A Crimes against the person
# 330933           A Crimes against the person
#
#                         Offence Subdivision  \
# 0          A20 Assault and related offences
# 1           Other crimes against the person
# 2                                 B40 Theft
# 3                                 B40 Theft
# 4       D10 Weapons and explosives offences
# ...                                     ...
# 330929                  B20 Property damage
# 330930         B30 Burglary/Break and enter
# 330931               E20 Breaches of orders
# 330932     A20 Assault and related offences
# 330933      Other crimes against the person
#
#                                     Offence Subgroup  Incidents Recorded
# 0                        A212 Non-FV Serious assault                   1
# 1                    Other crimes against the person                   1
# 2                     B42 Steal from a motor vehicle                   2
# 3                                    B49 Other theft                   1
# 4                              D11 Firearms offences                   1
# ...                                              ...                 ...
# 330929                           B21 Criminal damage                   1
# 330930  B322 Non-residential non-aggravated burglary                   1
# 330931                 E22 Breach intervention order                   1
# 330932                   A212 Non-FV Serious assault                   1
# 330933               Other crimes against the person                   1
#
# [330934 rows x 9 columns]

# %% [markdown]
# ## Feature selection

# %%
# feature selection
crime_df = crime_df[['Year', 'Postcode', 'Suburb/Town Name', 'Incidents Recorded']]
crime_df
# Out:
#         Year  Postcode Suburb/Town Name  Incidents Recorded
# 0       2023      3691         Dederang                   1
# 1       2023      3691         Dederang                   1
# 2       2023      3691         Dederang                   2
# 3       2023      3691         Dederang                   1
# 4       2023      3691         Dederang                   1
# ...      ...       ...              ...                 ...
# 330929  2014      3489            Tempy                   1
# 330930  2014      3489            Tempy                   1
# 330931  2014      3489            Tempy                   1
# 330932  2014      3491    Patchewollock                   1
# 330933  2014      3491    Patchewollock                   1
#
# [330934 rows x 4 columns]

# %% [markdown]
# # Apply agrregation
#
# #### Group by 'Suburb/Town Name', 'Postcode', 'Year' and count the total crime cases by suburbs

# %%
# Group by 'Suburb/Town Name', 'Postcode', 'Year'
suburb_crime_counts = crime_df.groupby(['Suburb/Town Name', 'Postcode', 'Year'])['Incidents Recorded'].sum().reset_index()

# %%
suburb_crime_counts
# Out:
#       Suburb/Town Name  Postcode  Year  Incidents Recorded
# 0             Abbeyard      3737  2015                   4
# 1             Abbeyard      3737  2017                   1
# 2             Abbeyard      3737  2019                   3
# 3             Abbeyard      3737  2021                   1
# 4           Abbotsford      3067  2014                 793
# ...                ...       ...   ...                 ...
# 23290          Zeerust      3634  2022                   2
# 23291          Zeerust      3634  2023                   8
# 23292        Zumsteins      3401  2018                   2
# 23293        Zumsteins      3401  2019                   2
# 23294        Zumsteins      3401  2022                   2
#
# [23295 rows x 4 columns]

# %%
# Save to Raw
suburb_crime_counts.to_csv('../data/raw/suburb_crime_counts.csv', index=False)  # Set index=False to exclude the index column

# %% [markdown]
# However, it is important to note that the suburb/Town Name may not be consistent with our SAL name as data is from different provider.
# We will find a point geometry for each suburb for later visualisation and merging

# %% [markdown]
# # Create a point geometry to the suburb_crime_counts
#
# To do this we will consider combining the crime count data with victoria' postcode data frame.
#
# As postcode data contain postcode (a common feature) and different locality (suburb) which we will be use to match with the "Suburb/Town Name" attribute in our crime data frame by similarity score.
#
# Most importantly postcode data contains point geometry for the locality.
#
# ## Combine crime count with victoria postcode data
# Join by postcode, and select for most similar name for the locality name and Suburb/Town Name from two the data

# %%
# import the postcode data
Postcode_df = pd.read_csv("../data/raw/location_postcode.csv")

# %%
Postcode_df
# Out:
#       postcode         locality  SA2_MAINCODE_2016   SA2_NAME_2016  \
# 0         3000        MELBOURNE        206041122.0       Melbourne
# 1         3001        MELBOURNE        206041122.0       Melbourne
# 2         3002   EAST MELBOURNE        206041119.0  East Melbourne
# 3         3003   WEST MELBOURNE        206041127.0  West Melbourne
# 4         3004        MELBOURNE        206041126.0       Southbank
# ...        ...              ...                ...             ...
# 3532      8120        MELBOURNE        206041122.0       Melbourne
# 3533      8205        MELBOURNE        206041122.0       Melbourne
# 3534      8785        DANDENONG        212041311.0       Dandenong
# 3535      8785  DANDENONG SOUTH        212041311.0       Dandenong
# 3536      9999       NORTH POLE        206041122.0       Melbourne
#
#       Lat_precise  Long_precise
# 0      -37.815207    144.963937
# 1      -37.813628    144.963058
# 2      -37.816144    144.980459
# 3      -37.811450    144.925397
# 4      -37.830158    144.980459
# ...           ...           ...
# 3532   -37.813628    144.963058
# 3533   -37.813628    144.963058
# 3534   -37.984781    145.213991
# 3535   -37.984781    145.213991
# 3536   -37.815207    144.963937
#
# [3537 rows x 6 columns]

# %% [markdown]
# Notice how the locality value are all in capital case, we will convert all Suburb/Town Name in the suburb_crime_counts and locality in postcode to lowercase for laters string comparision
#
# We will not using SA2_NAME and CODE in postcode df as they were from 2016, we will mainly focusing on the locality (suburb) and the lat and long for laters merging

# %%
# Lower case the Suburb/Town Name in crime count data frame
suburb_crime_counts['Suburb/Town Name'] = suburb_crime_counts['Suburb/Town Name'].str.lower()
# Lower case the locality in postcode data
Postcode_df['locality'] = Postcode_df['locality'].str.lower()
# Drop SA2_MAINCODE_2016 and SA2_NAME_2016 in postcode data
Postcode_df = Postcode_df.drop(columns=['SA2_MAINCODE_2016', 'SA2_NAME_2016'])

# %% [markdown]
# #### First join suburb_crime_counts and  Postcode_df by left join on postcode number

# %%
# Merge the crime data with postcode by postcode number first
crime_count_n_locality= suburb_crime_counts.merge(Postcode_df, left_on='Postcode', right_on='postcode', how='left')

# %%
crime_count_n_locality
# Out:
#        Suburb/Town Name  Postcode  Year  Incidents Recorded  postcode  \
# 0              abbeyard      3737  2015                   4      3737
# 1              abbeyard      3737  2015                   4      3737
# 2              abbeyard      3737  2015                   4      3737
# 3              abbeyard      3737  2015                   4      3737
# 4              abbeyard      3737  2015                   4      3737
# ...                 ...       ...   ...                 ...       ...
# 286037        zumsteins      3401  2022                   2      3401
# 286038        zumsteins      3401  2022                   2      3401
# 286039        zumsteins      3401  2022                   2      3401
# 286040        zumsteins      3401  2022                   2      3401
# 286041        zumsteins      3401  2022                   2      3401
#
#              locality  Lat_precise  Long_precise
# 0            abbeyard   -37.021325    146.764065
# 1           barwidgee   -36.509837    146.777018
# 2       buffalo river   -36.618382    146.681521
# 3        dandongadale   -36.911853    146.699920
# 4             gapsted   -36.514069    146.656295
# ...               ...          ...           ...
# 286037         wallup   -36.360516    142.245009
# 286038        wartook   -37.054612    142.343663
# 286039      wombelano   -37.015700    141.594000
# 286040      wonwondah   -36.917261    142.257961
# 286041      zumsteins   -37.118787    142.384236
#
# [286042 rows x 8 columns]

# %%
# Check if there is Suburb/Town Name that didn't get a macth
crime_count_n_locality[crime_count_n_locality.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Suburb/Town Name, Postcode, Year, Incidents Recorded, postcode, locality, Lat_precise, Long_precise]
# Index: []

# %% [markdown]
# #### Then compute similarity score between locality and Suburb/Town Name, and select the matched data/row with highest simialrity score for each (Suburb/Town Name)

# %%
# Create a new column name similarityscore that store similarlity score between locality and Suburb/Town Name
crime_count_n_locality['SimilarityScore'] = crime_count_n_locality.apply(
    lambda row: fuzz.ratio(row['Suburb/Town Name'], row['locality']),
    axis=1
)

# %%
crime_count_n_locality
# Out:
#        Suburb/Town Name  Postcode  Year  Incidents Recorded  postcode  \
# 0              abbeyard      3737  2015                   4      3737
# 1              abbeyard      3737  2015                   4      3737
# 2              abbeyard      3737  2015                   4      3737
# 3              abbeyard      3737  2015                   4      3737
# 4              abbeyard      3737  2015                   4      3737
# ...                 ...       ...   ...                 ...       ...
# 286037        zumsteins      3401  2022                   2      3401
# 286038        zumsteins      3401  2022                   2      3401
# 286039        zumsteins      3401  2022                   2      3401
# 286040        zumsteins      3401  2022                   2      3401
# 286041        zumsteins      3401  2022                   2      3401
#
#              locality  Lat_precise  Long_precise  SimilarityScore
# 0            abbeyard   -37.021325    146.764065              100
# 1           barwidgee   -36.509837    146.777018               47
# 2       buffalo river   -36.618382    146.681521               29
# 3        dandongadale   -36.911853    146.699920               20
# 4             gapsted   -36.514069    146.656295               40
# ...               ...          ...           ...              ...
# 286037         wallup   -36.360516    142.245009               13
# 286038        wartook   -37.054612    142.343663               12
# 286039      wombelano   -37.015700    141.594000               33
# 286040      wonwondah   -36.917261    142.257961               11
# 286041      zumsteins   -37.118787    142.384236              100
#
# [286042 rows x 9 columns]

# %% [markdown]
# #### Select the matched locality with highest Simialrity Score with Suburb/Town Name

# %%
# Group by 'Suburb/Town Name' and 'Year' and select row of the data with the highest 'SimilarityScore'
crime_count_n_locality = crime_count_n_locality.loc[crime_count_n_locality.groupby(['Suburb/Town Name','Year'])['SimilarityScore'].idxmax()]

# %%
crime_count_n_locality
# Out:
#        Suburb/Town Name  Postcode  Year  Incidents Recorded  postcode  \
# 0              abbeyard      3737  2015                   4      3737
# 15             abbeyard      3737  2017                   1      3737
# 30             abbeyard      3737  2019                   3      3737
# 45             abbeyard      3737  2021                   1      3737
# 60           abbotsford      3067  2014                 793      3067
# ...                 ...       ...   ...                 ...       ...
# 285889          zeerust      3634  2022                   2      3634
# 285897          zeerust      3634  2023                   8      3634
# 285945        zumsteins      3401  2018                   2      3401
# 285993        zumsteins      3401  2019                   2      3401
# 286041        zumsteins      3401  2022                   2      3401
#
#           locality  Lat_precise  Long_precise  SimilarityScore
# 0         abbeyard   -37.021325    146.764065              100
# 15        abbeyard   -37.021325    146.764065              100
# 30        abbeyard   -37.021325    146.764065              100
# 45        abbeyard   -37.021325    146.764065              100
# 60      abbotsford   -37.802360    144.998362              100
# ...            ...          ...           ...              ...
# 285889     zeerust   -36.270201    145.397333              100
# 285897     zeerust   -36.270201    145.397333              100
# 285945   zumsteins   -37.118787    142.384236              100
# 285993   zumsteins   -37.118787    142.384236              100
# 286041   zumsteins   -37.118787    142.384236              100
#
# [23046 rows x 9 columns]

# %% [markdown]
# #### Check data with poor Simialrity score

# %%
# Check data with mis_matched Suburb/Town Name to locality
mis_matched = crime_count_n_locality[crime_count_n_locality['SimilarityScore'] < 100]
mis_matched
# Out:
#        Suburb/Town Name  Postcode  Year  Incidents Recorded  postcode  \
# 59863             cokum      3530  2015                   1      3530
# 59867             cokum      3530  2018                   1      3530
# 59871             cokum      3530  2019                   1      3530
# 59875             cokum      3530  2020                   1      3530
# 59879             cokum      3530  2021                   1      3530
# 83490         eddington      3463  2022                   1      3463
# 140476    lake eppalock      3523  2016                   1      3523
# 140486    lake eppalock      3523  2017                   2      3523
# 140496    lake eppalock      3523  2018                   1      3523
# 140506    lake eppalock      3523  2019                   1      3523
# 140526    lake eppalock      3523  2023                   2      3523
# 171373         mirimbah      3723  2016                   2      3723
# 171399         mirimbah      3723  2021                   1      3723
# 171425         mirimbah      3723  2023                   1      3723
# 248301         timbarra      3893  2014                   1      3893
# 248304         timbarra      3893  2020                   1      3893
# 248307         timbarra      3893  2021                   1      3893
# 265889     watchem west      3393  2023                   1      3393
#
#              locality  Lat_precise  Long_precise  SimilarityScore
# 59863          culgoa   -35.717845    143.104025               36
# 59867          culgoa   -35.717845    143.104025               36
# 59871          culgoa   -35.717845    143.104025               36
# 59875          culgoa   -35.717845    143.104025               36
# 59879          culgoa   -35.717845    143.104025               36
# 83490          maldon   -36.998046    144.068599               40
# 140476     ladys pass   -36.826039    144.686299               43
# 140486     ladys pass   -36.826039    144.686299               43
# 140496     ladys pass   -36.826039    144.686299               43
# 140506     ladys pass   -36.826039    144.686299               43
# 140526     ladys pass   -36.826039    144.686299               43
# 171373         piries   -37.159326    146.127394               43
# 171399         piries   -37.159326    146.127394               43
# 171425         piries   -37.159326    146.127394               43
# 248301       stirling   -37.451889    147.710104               38
# 248304       stirling   -37.451889    147.710104               38
# 248307       stirling   -37.451889    147.710104               38
# 265889  warracknabeal   -36.252755    142.391955               32

# %% [markdown]
# By obseriving the data frame we see that there are 18 row of data has mismatched Suburb/Town Name and locality. Which suggest that most data were correcly matched between (Yeahhhhhhhhhhhh).
#
# We can choose to retain these data as they all coming from same postcode region, and their lat and long will be somewhere close to their actual location.
#
# However, as these mis matched data mostly coming from "cokum", ""watchem west", "timbarra", "eddington", "lake eppalock" and "mirimbah" with each only contain 1-2 incident record. Hence we can choose to drop these data out as they will be negligible

# %%
# Retain rows with correctly matched Suburb/Town Name === 'SimilarityScore'=100
crime_count_n_locality = crime_count_n_locality[crime_count_n_locality['SimilarityScore'] == 100]
crime_count_n_locality.reset_index(drop=True, inplace=True)

# %%
crime_count_n_locality
# Out:
#       Suburb/Town Name  Postcode  Year  Incidents Recorded  postcode  \
# 0             abbeyard      3737  2015                   4      3737
# 1             abbeyard      3737  2017                   1      3737
# 2             abbeyard      3737  2019                   3      3737
# 3             abbeyard      3737  2021                   1      3737
# 4           abbotsford      3067  2014                 793      3067
# ...                ...       ...   ...                 ...       ...
# 23023          zeerust      3634  2022                   2      3634
# 23024          zeerust      3634  2023                   8      3634
# 23025        zumsteins      3401  2018                   2      3401
# 23026        zumsteins      3401  2019                   2      3401
# 23027        zumsteins      3401  2022                   2      3401
#
#          locality  Lat_precise  Long_precise  SimilarityScore
# 0        abbeyard   -37.021325    146.764065              100
# 1        abbeyard   -37.021325    146.764065              100
# 2        abbeyard   -37.021325    146.764065              100
# 3        abbeyard   -37.021325    146.764065              100
# 4      abbotsford   -37.802360    144.998362              100
# ...           ...          ...           ...              ...
# 23023     zeerust   -36.270201    145.397333              100
# 23024     zeerust   -36.270201    145.397333              100
# 23025   zumsteins   -37.118787    142.384236              100
# 23026   zumsteins   -37.118787    142.384236              100
# 23027   zumsteins   -37.118787    142.384236              100
#
# [23028 rows x 9 columns]

# %% [markdown]
# ### Feature Selection/Drop duplicate/unnecessary columns

# %%
# Drop the specified columns
crime_count_df = crime_count_n_locality.drop(columns=['postcode', 'locality', 'SimilarityScore'])

# %%
crime_count_df
# Out:
#       Suburb/Town Name  Postcode  Year  Incidents Recorded  Lat_precise  \
# 0             abbeyard      3737  2015                   4   -37.021325
# 1             abbeyard      3737  2017                   1   -37.021325
# 2             abbeyard      3737  2019                   3   -37.021325
# 3             abbeyard      3737  2021                   1   -37.021325
# 4           abbotsford      3067  2014                 793   -37.802360
# ...                ...       ...   ...                 ...          ...
# 23023          zeerust      3634  2022                   2   -36.270201
# 23024          zeerust      3634  2023                   8   -36.270201
# 23025        zumsteins      3401  2018                   2   -37.118787
# 23026        zumsteins      3401  2019                   2   -37.118787
# 23027        zumsteins      3401  2022                   2   -37.118787
#
#        Long_precise
# 0        146.764065
# 1        146.764065
# 2        146.764065
# 3        146.764065
# 4        144.998362
# ...             ...
# 23023    145.397333
# 23024    145.397333
# 23025    142.384236
# 23026    142.384236
# 23027    142.384236
#
# [23028 rows x 6 columns]

# %% [markdown]
# #### Convert the crime_count_n_locality to a geodataframe

# %%
# Convert the dataframe to a geodataframe
geometry = [Point(xy) for xy in zip(crime_count_df['Long_precise'], crime_count_df['Lat_precise'])]
crime_count_gpd = gpd.GeoDataFrame(crime_count_df, geometry=geometry)
# drop lat and long columns
crime_count_gpd = crime_count_gpd.drop(columns=['Long_precise', 'Lat_precise'])

# %%
crime_count_gpd
# Out:
#       Suburb/Town Name  Postcode  Year  Incidents Recorded  \
# 0             abbeyard      3737  2015                   4
# 1             abbeyard      3737  2017                   1
# 2             abbeyard      3737  2019                   3
# 3             abbeyard      3737  2021                   1
# 4           abbotsford      3067  2014                 793
# ...                ...       ...   ...                 ...
# 23023          zeerust      3634  2022                   2
# 23024          zeerust      3634  2023                   8
# 23025        zumsteins      3401  2018                   2
# 23026        zumsteins      3401  2019                   2
# 23027        zumsteins      3401  2022                   2
#
#                           geometry
# 0      POINT (146.76407 -37.02132)
# 1      POINT (146.76407 -37.02132)
# 2      POINT (146.76407 -37.02132)
# 3      POINT (146.76407 -37.02132)
# 4      POINT (144.99836 -37.80236)
# ...                            ...
# 23023  POINT (145.39733 -36.27020)
# 23024  POINT (145.39733 -36.27020)
# 23025  POINT (142.38424 -37.11879)
# 23026  POINT (142.38424 -37.11879)
# 23027  POINT (142.38424 -37.11879)
#
# [23028 rows x 5 columns]

# %% [markdown]
# ### Save as a copy in raw

# %%
crime_count_gpd.to_file('../data/raw/crime_count_with_point_geo.geojson', driver="GeoJSON")  # Specify the driver based on the desired output format
